# %%
import pandas as pd

# %%
#stats in the 2015-16 season not SIGNED
calls15_16 = pd.read_csv("data/Season15-16.csv")
calls15_16.describe()
# Out:
#        games_played  team_games_played       goals     assists      points  \
# count    100.000000          100.00000  100.000000  100.000000  100.000000
# mean      37.600000           38.39000   14.310000   20.890000   35.200000
# std        2.853316            2.54612    4.980153    5.754041    7.362202
# min       29.000000           31.00000    2.000000    9.000000   27.000000
# 25%       36.000000           37.00000   11.000000   17.000000   29.000000
# 50%       38.000000           38.00000   14.000000   21.000000   33.000000
# 75%       39.000000           40.00000   18.000000   25.000000   41.000000
# max       43.000000           44.00000   29.000000   40.000000   55.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count      100.000000        100.000000       100.000000       100.000000
# mean         0.381800          0.553100         0.935400         4.260000
# ...

# %%
###signed players of  2015-16

callsSigned15_16 = pd.read_csv("data/NHLsigned20152016.csv")
callsSigned15_16.describe()
# Out:
#        games_played  team_games_played      goals    assists     points  \
# count     35.000000          35.000000  35.000000  35.000000  35.000000
# mean      37.742857          38.828571  15.542857  24.285714  39.828571
# std        2.417374           2.684221   6.757753   6.519525  10.048370
# min       33.000000          34.000000   4.000000  13.000000  30.000000
# 25%       36.000000          37.000000  11.000000  20.500000  32.500000
# 50%       38.000000          38.000000  14.000000  24.000000  36.000000
# 75%       40.000000          41.000000  19.000000  26.500000  45.000000
# max       42.000000          44.000000  35.000000  47.000000  71.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count       35.000000         35.000000        35.000000        35.000000
# mean         0.411714          0.645429         1.056286         4.400000
# std          0.178136          0.174800         0.260690         2.659058
# ...

# %%
####comparing the Signed to Unsigned  players

total20152016 = callsSigned15_16.describe()-calls15_16.describe()
total20152016
# Out:
#          assists  assists_per_game     blocks  faceoff_percentage  \
# count -65.000000        -65.000000 -65.000000                 NaN
# mean    3.395714          0.092329   3.918571                 NaN
# std     0.765483          0.036355   0.477464                 NaN
# min     4.000000          0.140000   6.000000                 NaN
# 25%     3.500000          0.065000   3.500000                 NaN
# 50%     3.000000          0.075000   2.000000                 NaN
# 75%     1.500000          0.070000   2.750000                 NaN
# max     7.000000          0.260000 -42.000000                 NaN
#
#        faceoffs_lost  faceoffs_won  game_winning_goals  games_played  \
# count     -65.000000    -65.000000          -65.000000    -65.000000
# mean       34.701429     30.554286            0.075714      0.142857
# std        11.749638      3.306265            0.240194     -0.435942
# min         0.000000      0.000000            0.000000      4.000000
# ...

# %%
#stats in the 2016-17 season unsigned players
calls16_17 = pd.read_csv("data/Season16-17.csv")
calls16_17.describe()
# Out:
#        games_played  team_games_played       goals     assists      points  \
# count    104.000000         104.000000  104.000000  104.000000  104.000000
# mean      37.519231          38.596154   14.317308   21.182692   35.500000
# std        3.497519           2.455504    5.621154    6.647526    8.717798
# min       25.000000          31.000000    3.000000   10.000000   27.000000
# 25%       36.000000          37.000000   10.000000   16.000000   29.000000
# 50%       38.000000          39.000000   14.000000   20.000000   33.000000
# 75%       40.000000          40.000000   18.000000   25.250000   37.250000
# max       45.000000          45.000000   31.000000   39.000000   63.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count      104.000000        104.000000       104.000000       104.000000
# mean         0.383269          0.566827         0.949423         4.865385
# ...

# %%
#stats in the 2016-17 season signed players
callsSigned16_17 = pd.read_csv("data/NHLsigned20162017.csv")
callsSigned16_17.describe()
# Out:
#        games_played  team_games_played      goals    assists     points  \
# count     41.000000          41.000000  41.000000  41.000000  41.000000
# mean      36.439024          38.512195  15.951220  23.024390  38.975610
# std        2.881395           2.802873   5.064342   5.820171   6.478765
# min       30.000000          31.000000   5.000000  13.000000  32.000000
# 25%       35.000000          36.000000  13.000000  19.000000  34.000000
# 50%       36.000000          39.000000  16.000000  23.000000  37.000000
# 75%       39.000000          40.000000  21.000000  27.000000  42.000000
# max       43.000000          44.000000  26.000000  36.000000  57.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count       41.000000         41.000000        41.000000        41.000000
# mean         0.441463          0.630976         1.072683         4.951220
# std          0.145663          0.145255         0.171538         3.193362
# ...

# %%
###comparing 2016-17 results
total20162017 = callsSigned16_17.describe()-calls16_17.describe()
total20162017
# Out:
#          assists  assists_per_game     blocks  faceoffs_lost  faceoffs_won  \
# count -63.000000        -63.000000 -63.000000     -63.000000    -63.000000
# mean    1.841698          0.064149  -1.380159      28.990854     29.314728
# std    -0.827355         -0.030974  -0.297141     -10.647726    -14.244631
# min     3.000000          0.060000   2.000000       0.000000      0.000000
# 25%     3.000000          0.110000  -1.000000      12.250000     12.250000
# 50%     3.000000          0.100000  -2.000000      84.000000    100.500000
# 75%     1.750000          0.027500  -1.000000      17.000000     51.250000
# max    -3.000000         -0.060000  -3.000000     -68.000000    -95.000000
#
#        game_winning_goals  games_played      goals  goals_per_game  \
# count          -63.000000    -63.000000 -63.000000      -63.000000
# mean             0.366323     -1.080206   1.633912        0.058194
# std              0.062354     -0.616123  -0.556811       -0.003284
# ...

# %%
#stats in the 2017-18 season
calls17_18 = pd.read_csv("data/Season17-18.csv")
calls17_18.describe()
# Out:
#        games_played  team_games_played       goals     assists      points  \
# count     106.00000         106.000000  106.000000  106.000000  106.000000
# mean       37.90566          38.707547   13.877358   20.773585   34.650943
# std         3.02223           2.503205    4.894512    5.680850    5.958655
# min        29.00000          31.000000    4.000000    8.000000   28.000000
# 25%        36.00000          37.000000   10.000000   16.000000   30.000000
# 50%        37.00000          38.000000   13.000000   21.000000   33.000000
# 75%        40.00000          40.000000   17.000000   24.000000   38.000000
# max        44.00000          44.000000   29.000000   40.000000   55.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count      106.000000        106.000000       106.000000       106.000000
# mean         0.367830          0.549245         0.916981         4.830189
# ...

# %%
#stats in the 2017-18 season
callsSigned17_18 = pd.read_csv("data/NHLsigned20172018.csv")
callsSigned17_18.describe()
# Out:
#        games_played  team_games_played      goals    assists     points  \
# count     37.000000          37.000000  37.000000  37.000000  37.000000
# mean      37.621622          38.864865  14.216216  22.945946  37.162162
# std        3.714471           2.162331   5.907317   5.656589   8.163311
# min       22.000000          33.000000   2.000000  15.000000  30.000000
# 25%       36.000000          37.000000  11.000000  19.000000  31.000000
# 50%       38.000000          40.000000  13.000000  21.000000  33.000000
# 75%       40.000000          40.000000  17.000000  28.000000  43.000000
# max       42.000000          44.000000  30.000000  35.000000  60.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count       37.000000         37.000000        37.000000        37.000000
# mean         0.386486          0.609189         0.996216         5.081081
# std          0.178796          0.134130         0.232980         3.209174
# ...

# %%
###comparing 2017-18 results
total20172018 = callsSigned17_18.describe()-calls17_18.describe()
total20172018
# Out:
#          assists  assists_per_game     blocks  faceoffs_lost  faceoffs_won  \
# count -69.000000        -69.000000 -69.000000     -69.000000    -69.000000
# mean    2.172361          0.059944  -2.007649      53.705252     48.191229
# std    -0.024261         -0.012966  -2.714713      18.746672     14.269352
# min     7.000000          0.160000   2.000000       0.000000      0.000000
# 25%     3.000000          0.087500  -2.000000      -1.000000      1.000000
# 50%     0.000000          0.030000   0.000000     113.500000     99.000000
# 75%     4.000000          0.042500  -1.000000      75.250000     73.750000
# max    -5.000000         -0.150000 -54.000000     -44.000000    -48.000000
#
#        game_winning_goals  games_played      goals  goals_per_game  \
# count          -69.000000    -69.000000 -69.000000      -69.000000
# mean            -0.178735     -0.284039   0.338858        0.018656
# std              0.036043      0.692242   1.012806        0.048061
# ...

# %%
#stats in the 2018-19 season
calls18_19 = pd.read_csv("data/Season18-19.csv")
calls18_19.describe()
# Out:
#        games_played  team_games_played       goals     assists      points  \
# count    119.000000         119.000000  119.000000  119.000000  119.000000
# mean      37.621849          38.361345   13.176471   19.731092   32.907563
# std        2.764765           2.420713    4.600381    5.364190    6.471570
# min       26.000000          31.000000    3.000000    8.000000   26.000000
# 25%       36.000000          37.000000   10.000000   16.000000   27.000000
# 50%       38.000000          39.000000   13.000000   19.000000   31.000000
# 75%       39.000000          40.000000   16.000000   24.000000   37.000000
# max       42.000000          42.000000   25.000000   35.000000   50.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count      119.000000        119.000000       119.000000       119.000000
# mean         0.351345          0.525966         0.877059         4.260504
# ...

# %%
#stats in the 2018-19 season Signed players
callsSigned18_19 = pd.read_csv("data/NHLsigned20182019.csv")
callsSigned18_19.describe()
# Out:
#        games_played  team_games_played      goals    assists     points  \
# count     28.000000          28.000000  28.000000  28.000000  28.000000
# mean      37.178571          38.464286  12.678571  22.321429  35.000000
# std        3.559584           2.603163   4.807814   6.588731   5.912949
# min       27.000000          33.000000   3.000000  13.000000  29.000000
# 25%       36.000000          36.000000   9.750000  17.500000  30.000000
# 50%       37.500000          38.500000  13.000000  23.000000  33.500000
# 75%       40.000000          41.000000  16.000000  26.250000  39.000000
# max       42.000000          42.000000  23.000000  39.000000  49.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count       28.000000         28.000000        28.000000        28.000000
# mean         0.341786          0.607143         0.948214         5.214286
# std          0.127948          0.194762         0.183122         2.454884
# ...

# %%
###comparing 2018-19 results
total20182019 = callsSigned18_19.describe()-calls18_19.describe()
total20182019
# Out:
#          assists  assists_per_game     blocks  faceoffs_lost  faceoffs_won  \
# count -91.000000        -91.000000 -91.000000     -91.000000    -91.000000
# mean    2.590336          0.081176   4.111345     -15.119748    -16.023109
# std     1.224541          0.048867  -0.269445     -24.188482    -31.224058
# min     5.000000          0.110000   5.000000       0.000000      0.000000
# 25%     1.500000          0.037500   4.500000      -2.250000     -1.750000
# 50%     4.000000          0.105000   3.000000      10.500000      9.500000
# 75%     2.250000          0.077500   5.750000     -32.250000    -17.750000
# max     4.000000          0.210000   5.000000     -62.000000    -53.000000
#
#        game_winning_goals  games_played      goals  goals_per_game  \
# count          -91.000000    -91.000000 -91.000000      -91.000000
# mean            -0.002101     -0.443277  -0.497899       -0.009559
# std             -0.285571      0.794819   0.207433        0.004071
# ...

# %%
#stats in the 2019-20 season
calls19_20 = pd.read_csv("data/Season19-20.csv")
calls19_20.describe()
# Out:
#        games_played  team_games_played       goals  assists      points  \
# count    100.000000         100.000000  100.000000  100.000  100.000000
# mean      34.510000          35.600000   11.950000   18.050   30.000000
# std        2.808699           2.197335    4.274366    5.056    4.737557
# min       25.000000          29.000000    2.000000    7.000   25.000000
# 25%       33.000000          34.000000    9.000000   14.750   27.000000
# 50%       34.000000          36.000000   12.000000   17.000   28.000000
# 75%       36.000000          37.000000   14.000000   21.000   32.000000
# max       41.000000          41.000000   23.000000   32.000   45.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count      100.000000        100.000000       100.000000       100.000000
# mean         0.347400          0.527100         0.874900         3.730000
# std          0.125365          0.155883         0.155755         2.526046
# ...

# %%
#stats in the 2019-20 season signed players
callsSigned19_20 = pd.read_csv("data/NHLsigned20192020.csv")
callsSigned19_20.describe()
# Out:
#        games_played  team_games_played      goals    assists     points  \
# count     42.000000          42.000000  42.000000  42.000000  42.000000
# mean      33.404762          34.357143  12.904762  20.642857  33.547619
# std        2.650904           1.897642   5.069322   6.423362   5.726287
# min       27.000000          29.000000   5.000000   8.000000  27.000000
# 25%       32.250000          34.000000   9.250000  17.000000  29.250000
# 50%       34.000000          34.000000  13.000000  21.500000  32.500000
# 75%       35.000000          36.000000  16.000000  23.750000  36.750000
# max       38.000000          38.000000  27.000000  42.000000  52.000000
#
#        goals_per_game  assists_per_game  points_per_game  powerplay_goals  \
# count       42.000000         42.000000        42.000000        42.000000
# mean         0.392143          0.620476         1.011429         4.309524
# std          0.166785          0.193150         0.198514         2.414268
# ...

# %%
###comparing 2019-20 results
total20192020 = callsSigned19_20.describe()-calls19_20.describe()
total20192020
# Out:
#          assists  assists_per_game     blocks  faceoffs_lost  faceoffs_won  \
# count -58.000000        -58.000000 -58.000000     -58.000000    -58.000000
# mean    2.592857          0.093376   2.689524     -10.731905    -12.943333
# std     1.367363          0.037267   2.460942     -19.297382    -29.946958
# min     1.000000          0.060000  -1.000000       0.000000      0.000000
# 25%     2.250000          0.075000   0.000000      -4.750000     -3.000000
# 50%     4.500000          0.130000   0.000000       5.500000     15.500000
# 75%     2.750000          0.082500   5.750000     -34.250000    -46.500000
# max    10.000000          0.300000 -10.000000     -98.000000   -163.000000
#
#        game_winning_goals  games_played      goals  goals_per_game  \
# count          -58.000000    -58.000000 -58.000000      -58.000000
# mean             0.147143     -1.105238   0.954762        0.044743
# std              0.514832     -0.157794   0.794956        0.041420
# ...

# %%
import seaborn as sns
sns.violinplot( y=calls19_20["points"], x=calls19_20["games_played"])

# %%
import seaborn as sns
sns.violinplot( y=calls18_19["points"], x=calls18_19["games_played"])

# %%
import seaborn as sns
sns.violinplot( y=calls17_18["points"], x=calls17_18["games_played"])

# %%
seasonTotals = calls19_20.describe(include='all').loc['mean']

# %%
seasonTotals.plot.bar().set_title('2019-2020 Season')
# Out:
# Text(0.5, 1.0, '2019-2020 Season')

# %%
seasonTotals1 = callsSigned19_20.describe(include='all').loc['mean']
seasonTotals1.plot.bar().set_title('2019-2020 Season')
# Out:
# Text(0.5, 1.0, '2019-2020 Season')

# %%
seasonTotals1 = calls18_19.describe(include='all').loc['mean']
seasonTotals1.plot.bar().set_title('2018-2019 Season')
# Out:
# Text(0.5, 1.0, '2018-2019 Season')

# %%
seasonTotals2 = calls17_18.describe(include='all').loc['mean']
seasonTotals2.plot.bar().set_title('2017-2018 Season')
# Out:
# Text(0.5, 1.0, '2017-2018 Season')

# %%
seasonTotals3 = calls16_17.describe(include='all').loc['mean']
seasonTotals3.plot.bar().set_title('2016-2017 Season')
# Out:
# Text(0.5, 1.0, '2016-2017 Season')

# %%
###signed players
seasonTotals4 = callsSigned19_20.describe(include='all').loc['mean']
seasonTotals4.plot.bar().set_title('2015-2016 Season')
# Out:
# Text(0.5, 1.0, '2015-2016 Season')
